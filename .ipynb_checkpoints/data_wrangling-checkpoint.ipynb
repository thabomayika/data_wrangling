# %% [markdown]
# ## 1. Visualising the data and removing Null values

# %%
import pandas as pd 
import numpy as np
import re

# %%
df = pd.read_csv('personality_scores.csv', sep=";")
df.head()
# Out:
#    ID Section 5 of 6 [I am always prepared.]  \
# 0   0                                 (3, 5)
# 1   1                                 (3, 5)
# 2   2                                 (3, 5)
# 3   3                                 (3, 5)
# 4   4                                 (3, 3)
#
#   Section 5 of 6 [I am easily disturbed.]  \
# 0                                  (4, 5)
# 1                                  (4, 5)
# 2                                  (4, 3)
# 3                                  (4, 5)
# 4                                  (4, 5)
#
#   Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
# 2                                             (3, 3)
# 3                                             (3, 3)
# 4                                             (3, 3)
#
#   Section 5 of 6 [I am full of ideas.]  \
# 0                               (5, 5)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1555 entries, 0 to 1554
# Data columns (total 70 columns):
# ID                                                                          1555 non-null int64
# Section 5 of 6 [I am always prepared.]                                      1555 non-null object
# Section 5 of 6 [I am easily disturbed.]                                     1555 non-null object
# Section 5 of 6 [I am exacting (demanding) in my work.]                      1555 non-null object
# Section 5 of 6 [I am full of ideas.]                                        1555 non-null object
# Section 5 of 6 [I am interested in people.]                                 1555 non-null object
# Section 5 of 6 [I am not interested in abstract ideas.]                     1555 non-null object
# Section 5 of 6 [I am not interested in other people's problems.]            1555 non-null object
# ...

# %%
new_df = df.drop_duplicates(keep="first")
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1555 entries, 0 to 1554
# Data columns (total 70 columns):
# ID                                                                          1555 non-null int64
# Section 5 of 6 [I am always prepared.]                                      1555 non-null object
# Section 5 of 6 [I am easily disturbed.]                                     1555 non-null object
# Section 5 of 6 [I am exacting (demanding) in my work.]                      1555 non-null object
# Section 5 of 6 [I am full of ideas.]                                        1555 non-null object
# Section 5 of 6 [I am interested in people.]                                 1555 non-null object
# Section 5 of 6 [I am not interested in abstract ideas.]                     1555 non-null object
# Section 5 of 6 [I am not interested in other people's problems.]            1555 non-null object
# ...

# %%
df.dropna(axis=1, how="all", inplace = True)

# %%
df.head()
# Out:
#    ID Section 5 of 6 [I am always prepared.]  \
# 0   0                                 (3, 5)
# 1   1                                 (3, 5)
# 2   2                                 (3, 5)
# 3   3                                 (3, 5)
# 4   4                                 (3, 3)
#
#   Section 5 of 6 [I am easily disturbed.]  \
# 0                                  (4, 5)
# 1                                  (4, 5)
# 2                                  (4, 3)
# 3                                  (4, 5)
# 4                                  (4, 5)
#
#   Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
# 2                                             (3, 3)
# 3                                             (3, 3)
# 4                                             (3, 3)
#
#   Section 5 of 6 [I am full of ideas.]  \
# 0                               (5, 5)
# ...

# %%
assert len(df) == len(new_df)

# %% [markdown]
# ### 2. Create new columns containing the total score of each of the personality test subscales.

# %%
# funtion for creating the scores of the new columns 
def convertData(row, Nums_Cat):
    count = 0
    for values in df.columns:
        lst = row[values]
        if type(lst) == str:
            cat = lst[1]
            result = int(lst[4])
            if cat == Nums_Cat:
                count += result
    return count

# %%
# applying the function above to the new columns 
df['Extraversion'] = df.apply(lambda row : convertData(row,'1'), axis = 1)
df['Agreeableness'] = df.apply(lambda row : convertData(row,'2'), axis = 1)
df['Conscientiousness'] = df.apply(lambda row : convertData(row,'3'), axis = 1)
df['Emotional Stability'] = df.apply(lambda row : convertData(row,'4'), axis = 1)
df['openness'] = df.apply(lambda row : convertData(row,'5'), axis = 1)

# %%
# printing the new dataset with new columns
df.head()
# Out:
#    ID Section 5 of 6 [I am always prepared.]  \
# 0   0                                 (3, 5)
# 1   1                                 (3, 5)
# 2   2                                 (3, 5)
# 3   3                                 (3, 5)
# 4   4                                 (3, 3)
#
#   Section 5 of 6 [I am easily disturbed.]  \
# 0                                  (4, 5)
# 1                                  (4, 5)
# 2                                  (4, 3)
# 3                                  (4, 5)
# 4                                  (4, 5)
#
#   Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
# 2                                             (3, 3)
# 3                                             (3, 3)
# 4                                             (3, 3)
#
#   Section 5 of 6 [I am full of ideas.]  \
# 0                               (5, 5)
# ...

# %% [markdown]
# # Question 2

# %% [markdown]
#  1. Importing the data, merging data and using the asssert statement to see if the lengths of the DataFrame is equal(==)

# %%
# Using Pandas to read into the file
df_departments = pd.read_csv('departments.csv', sep=';')
df_departments.head()
# Out:
#    ID Department
# 0   0       Data
# 1   1       Data
# 2   2       Data
# 3   3       Data
# 4   4       Data

# %%
# Merging the two DataFrame using Pandas(pd)
df_merge = pd.merge(df, df_departments, on=None, how='outer')
df_merge.head()
# Out:
#    ID Section 5 of 6 [I am always prepared.]  \
# 0   0                                 (3, 5)
# 1   1                                 (3, 5)
# 2   2                                 (3, 5)
# 3   3                                 (3, 5)
# 4   4                                 (3, 3)
#
#   Section 5 of 6 [I am easily disturbed.]  \
# 0                                  (4, 5)
# 1                                  (4, 5)
# 2                                  (4, 3)
# 3                                  (4, 5)
# 4                                  (4, 5)
#
#   Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
# 2                                             (3, 3)
# 3                                             (3, 3)
# 4                                             (3, 3)
#
#   Section 5 of 6 [I am full of ideas.]  \
# 0                               (5, 5)
# ...

# %%
# using the assert statement to see if the length(len) of DataFrame is equal
assert len(df_departments) == len(df_merge)

# %% [markdown]
# *Trying to see if the length of the merged and department DataFrame is equal.
#
# *We have CONCLUDED that they are equal length

# %% [markdown]
# #### 2. Creating a condition that has to be met by the columns (named) and a new DataFrames

# %%
# finding the values that are less than 30 in the three columns 
df_merge[(df_merge['Agreeableness'] < 30) & (df_merge['Emotional Stability'] < 30) & (df_merge['Conscientiousness'] < 30)]
# Out:
#         ID Section 5 of 6 [I am always prepared.]  \
# 881    881                                 (3, 3)
# 1197  1197                                 (3, 5)
#
#      Section 5 of 6 [I am easily disturbed.]  \
# 881                                   (4, 1)
# 1197                                  (4, 5)
#
#      Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 881                                              (3, 1)
# 1197                                             (3, 1)
#
#      Section 5 of 6 [I am full of ideas.]  \
# 881                                (5, 5)
# 1197                               (5, 1)
#
#      Section 5 of 6 [I am interested in people.]  \
# 881                                       (2, 1)
# 1197                                      (2, 1)
#
#      Section 5 of 6 [I am not interested in abstract ideas.]  \
# 881                                              (5, 3)
# 1197                                             (5, 3)
#
# ...

# %%
# creating a new DataFrame with the columns stated below
Risk_status = pd.DataFrame(df_merge[['ID','Extraversion','Agreeableness','Conscientiousness','Emotional Stability','openness','Department']])
Risk_status.head()
# Out:
#    ID  Extraversion  Agreeableness  Conscientiousness  Emotional Stability  \
# 0   0            30             40                 48                   36
# 1   1            42             46                 46                   40
# 2   2            28             40                 40                   38
# 3   3            30             38                 38                   40
# 4   4            28             34                 46                   38
#
#    openness Department
# 0        42       Data
# 1        42       Data
# 2        42       Data
# 3        38       Data
# 4        36       Data

# %%
# funtion that is creating the high and low of the new columns
def risk_status(score, name):
    mean = df_merge[name].mean()
    standiv = df_merge[name].std()
    high = (mean + standiv)/2
    low = (mean - standiv)/2
    if score >= high:
        return 'high'
    else:
        return 'low'

# %%
# creating new columns for the merged DataFrame and calling the relevant columns  
df_merge['Extraversion levels'] = df_merge['Extraversion'].apply(lambda column : risk_status(column,'Extraversion'))
df_merge['Agreeableness levels'] = df_merge['Agreeableness'].apply(lambda column : risk_status(column,'Agreeableness'))
df_merge['Conscientiousness levels'] = df_merge['Conscientiousness'].apply(lambda column : risk_status(column,'Conscientiousness'))
df_merge['Emotional Stability levels'] = df_merge['Emotional Stability'].apply(lambda column : risk_status(column,'Emotional Stability'))
df_merge['openness levels'] = df_merge['openness'].apply(lambda column : risk_status(column,'openness'))
df_merge.loc[:, 'Agreeableness':'openness levels']
# Out:
#       Agreeableness  Conscientiousness  Emotional Stability  openness  \
# 0                40                 48                   36        42
# 1                46                 46                   40        42
# 2                40                 40                   38        42
# 3                38                 38                   40        38
# 4                34                 46                   38        36
# ...             ...                ...                  ...       ...
# 1550             48                 38                   44        44
# 1551             48                 40                   44        34
# 1552             44                 40                   46        48
# 1553             38                 48                   36        44
# 1554             44                 42                   40        30
#
#      Department Extraversion levels Agreeableness levels  \
# 0          Data                high                 high
# ...

# %%
# we are creating a new column called  
Risk_status['Risk Status'] = np.where(
    (Risk_status['Emotional Stability'] < 30) & \
    (Risk_status.Conscientiousness < 30) & (Risk_status.Agreeableness < 30), 'High risk', 'Low risk')
Risk_status.head()
# Out:
#    ID  Extraversion  Agreeableness  Conscientiousness  Emotional Stability  \
# 0   0            30             40                 48                   36
# 1   1            42             46                 46                   40
# 2   2            28             40                 40                   38
# 3   3            30             38                 38                   40
# 4   4            28             34                 46                   38
#
#    openness Department Risk Status
# 0        42       Data    Low risk
# 1        42       Data    Low risk
# 2        42       Data    Low risk
# 3        38       Data    Low risk
# 4        36       Data    Low risk

# %%
# we are calling the columns, grouping them and making them into a DataFrame 
summary = Risk_status[['Risk Status', 'Department']].groupby(['Risk Status', 'Department']).size()
pd.DataFrame(summary)
# Out:
#                            0
# Risk Status Department
# High risk   Copywriting    1
#             Data           1
# Low risk    Copywriting  325
#             Data         328
#             Design       120
#             Strategy     449
#             Web Dev      170
#             Web dev      161

# %%
summary = pd.pivot_table(summary, index=['Risk Status'],  columns=['Department'], margins=True, aggfunc=np.sum)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-8e0e365ee7ec> in <module>
# ----> 1 summary = pd.pivot_table(summary, index=['Risk Status'],  columns=['Department'], margins=True, aggfunc=np.sum)
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      85
#      86     else:
# ---> 87         values = data.columns
#      88         for key in keys:
#      89             try:
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ...

# %%
summary
# Out:
#             Agreeableness                                                   \
# Department    Copywriting     Data  Design Strategy Web Dev Web dev    All
# Risk Status
# High risk            22.0     28.0     NaN      NaN     NaN     NaN     50
# Low risk          13630.0  13924.0  5020.0  18970.0  7148.0  6848.0  65540
# All               13652.0  13952.0  5020.0  18970.0  7148.0  6848.0  65590
#
#             Conscientiousness                   ...       ID            \
# Department        Copywriting     Data  Design  ...  Web Dev   Web dev
# Risk Status                                     ...
# High risk                26.0     26.0     NaN  ...      NaN       NaN
# Low risk              13724.0  13958.0  5024.0  ...  19295.0  237314.0
# All                   13750.0  13984.0  5024.0  ...  19295.0  237314.0
#
#                         openness                                            \
# Department       All Copywriting     Data  Design Strategy Web Dev Web dev
# Risk Status
# ...
